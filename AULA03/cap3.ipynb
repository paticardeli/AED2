# %% [markdown]
# 1. (ENADE): Considere um algoritmo de busca sequencial que procura por um determinado valor em um vetor
# de tamanho n. Sobre a complexidade desse algoritmo, assinale a alternativa CORRETA:
# A. Melhor caso em tempo O(n) e pior caso em tempo O(n²).
# B. Melhor caso em tempo O(1) e pior caso em tempo O(n).
# C. Melhor caso e pior caso ambos O(log n).
# D. A complexidade independe de n (tempo constante, O(1)).
#
# resposta: b

# %% [markdown]
# 2. (TEÓRICA): Suponha que você tenha uma lista não ordenada com 100 nomes e deseja verificar se o nome
# "Mariana" está presente. Sobre o algoritmo de busca sequencial nesse contexto, é correto afirmar que:
# A. No pior caso, será necessário comparar "Mariana" com todos os 100 nomes da lista.
# B. Caso "Mariana" não esteja na lista, o algoritmo irá interromper a busca na metade, por eficiência.
# C. Se "Mariana" estiver na primeira posição, ainda assim serão verificadas todas as 100 posições para
# confirmar duplicatas.
# D. A busca sequencial não funciona com listas de strings, apenas com números, devido às comparações.
#
#
# resposta a

# %% [markdown]
# 3. (TEÓRICA): Considere a implementação clássica da busca sequencial que retorna o índice da primeira
# ocorrência do valor alvo ou -1 se não encontrar. Dada uma lista L = [7, 12, 5, 12, 8], se chamarmos a
# função busca_sequencial(12, L), qual será o resultado retornado?
# A. 1
# B. 2
# C. 3
# D. -1
#
#
# reposta a

# %%
#4

def buscar_cliente(nome, lista_clientes):
    for i in range(len(lista_clientes)):
        if lista_clientes[i] == nome:
            return i
    return -1

clientes = ["ana", "bruno", "carlos", "daniel", "elisa"]
busca1 = "carlos"
busca2 = "fernanda"
pos1 = buscar_cliente(busca1, clientes)
if pos1 != -1:
    print(f"cliente {busca1} encontrado na posicao {pos1}.")
pos2 = buscar_cliente(busca2, clientes)
if pos2 != -1:
    print(f"cliente {busca2} encontrado na posicao {pos2}.")
else:
    print(f"cliente {busca2} nao encontrado na lista")
# Out:
# cliente carlos encontrado na posicao 2.
# cliente fernanda nao encontrado na lista

# %%
#5 
def conta_ocorrencias(valor, lista):
    contador = 0
    for i in lista:
        if i == valor:
            contador += 1
    return contador

print(conta_ocorrencias(3,[1,3,5,3,7]))
print(conta_ocorrencias("a", ["a", "b", "c", "a"]))
# Out:
# 2
# 2

# %%
#6
def remove_elementos(lista, valor):
    if len(lista) == 0:
        return None
    indice = -1
    for i in range(len(lista)):
        if lista[i] == valor:
            indice = i
            break
    if indice == -1:
        return None
    elementos_removido = lista[indice]
    for j in range(indice, len(lista)-1):
        lista[j] = lista[j+1]
    lista.pop()


dados = [10, 3 ,7, 34, 23, 2, 21]
print("lista original", dados)
rem = remove_elementos(dados, 23)
if rem is not None:
    print(f"valor {rem} removido")
else:
    print("valor nao encontrado ou lista vazia")
print("lista apos remocao:", dados)
# Out:
# lista original [10, 3, 7, 34, 23, 2, 21]
# valor nao encontrado ou lista vazia
# lista apos remocao: [10, 3, 7, 34, 2, 21]

# %%
#pj1 
def busca_sequencial(catalogo, titulo):
    for i in range(len(catalogo)):
        if catalogo[i] == titulo:
            return i
    return -1


def buscar_filme(catalogo, titulo):
    indice = busca_sequencial(catalogo, titulo)
    if indice != -1:
        return f"filme {titulo} encontrado na posicao {indice} do catalogo"
    else:
        return f"filme {titulo} nao encontrado"

catalogo_filmes = ["hobbit", "madagascar", "nemo" ]
titulo_buscado = input("Digite o titulo do filme que voce procura:")
resultado_busca = buscar_filme(catalogo_filmes, titulo_buscado)
print(resultado_busca)
# Out:
# Digite o titulo do filme que voce procura: nemo
# filme nemo encontrado na posicao 2 do catalogo

# %%
def busca_sequencial1(lista_convidados, nome):
     for i in range(len(lista_convidados)):
        if lista_convidados[i] == nome:
            return i
     return -1



def verificar_convidado(lista_convidados, nome):
    if busca_sequencial1(lista_convidados, nome)!= -1:
        return f"o convidado {nome} esta na lista"
    else:
        return f" o convidado {nome} nao foi encontrado na lista."

convidados = ["fabio", "renan", "marcelo", "rodrigo"]
nome_verificar = input("digite o nome do convidado para verificar")
resultado = verificar_convidado(convidados, nome_verificar)
print(resultado)
# Out:
# digite o nome do convidado para verificar fabio
# o convidado fabio esta na lista
