# %% [markdown]
# ## Capítulo 2
#
# #### Complexidade de Algoritmos

# %% [markdown]
# ##### Exercício 1:
# ###### Considere a função abaixo, que recebe uma lista e imprime o primeiro elemento:

# %%
def imprime_primeiro(lista):
 print(lista[0])

# %% [markdown]
# ##### Qual é a ordem de complexidade de tempo dessa função em termos de n (tamanho da lista)?

# %% [markdown]
# #### Resposta:
#
# ##### O tempo de execução não depende do tamanho da lista (n), pois o acesso a um índice específico é uma operação imediata.

# %% [markdown]
# #### Exercício 2:
# ##### Analise a complexidade da função encontrar_maximo(lista) que retorna o maior valor em uma lista:

# %%
def encontrar_maximo(lista):
 valor_maximo = lista[0]
 for numero in lista:
 if numero > valor_maximo:
 valor_maximo = numero
 return valor_maximo

# %% [markdown]
# ##### A lista de entrada tem n elementos. Qual a ordem de complexidade em função de n?

# %% [markdown]
# #### Resposta:
# ##### A ordem de complexidade é Linear $O(n)$.

# %% [markdown]
# ##### Exercício 3:
# ###### Qual a complexidade da busca binária? Considere que temos uma lista ordenada de tamanho n e a função abaixo procura um elemento alvo nessa lista (retornando o índice ou -1 se não encontrar):
